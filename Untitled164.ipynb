# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("https://homepage.boku.ac.at/leisch/MSA/datasets/mcdonalds.csv")

# %%
df.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
column_names=df.columns.tolist()

# %%
column_names
# Out:
# ['yummy',
#  'convenient',
#  'spicy',
#  'fattening',
#  'greasy',
#  'fast',
#  'cheap',
#  'tasty',
#  'expensive',
#  'healthy',
#  'disgusting',
#  'Like',
#  'Age',
#  'VisitFrequency',
#  'Gender']

# %%
df.shape
# Out:
# (1453, 15)

# %%
summary= df.iloc[:,[1,2,4,5]].describe()

# %%
summary
# Out:
#        convenient spicy greasy  fast
# count        1453  1453   1453  1453
# unique          2     2      2     2
# top           Yes    No    Yes   Yes
# freq         1319  1317    765  1308

# %%
df.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %% [markdown]
# # Descriptive Analysis

# %%
plt.hist(df["Age"],color="blue",edgecolor="black",alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Data')
plt.grid(True)
plt.show()

# %%
plt.boxplot(df['Age'], vert=False)
plt.xlabel('Age')
plt.title('Box Plot of Age')
plt.grid(True)
plt.show()

# %% [markdown]
# # Pre-Processing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %%
df.columns
# Out:
# Index(['yummy', 'convenient', 'spicy', 'fattening', 'greasy', 'fast', 'cheap',
#        'tasty', 'expensive', 'healthy', 'disgusting', 'Like', 'Age',
#        'VisitFrequency', 'Gender'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
for i in (df.columns):
    df[i]=df[i].replace(["Yes","No"],[1,0])

# %%
df["VisitFrequency"]=le.fit_transform(df["VisitFrequency"])

# %%
df["Gender"]=le.fit_transform(df["Gender"])

# %%
df.head()
# Out:
#    yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  expensive  \
# 0      0           1      0          1       0     1      1      0          1
# 1      1           1      0          1       1     1      1      1          1
# 2      0           1      1          1       1     1      0      1          1
# 3      1           1      0          1       1     1      1      1          0
# 4      0           1      0          1       1     1      1      0          0
#
#    healthy  disgusting Like  Age  VisitFrequency  Gender
# 0        0           0   -3   61               0       0
# 1        0           0   +2   51               0       0
# 2        1           0   +1   62               0       0
# 3        0           1   +4   69               4       0
# 4        1           0   +2   49               3       1

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df["Like"].unique()
# Out:
# array(['-3', '+2', '+1', '+4', 'I love it!+5', 'I hate it!-5', '-2', '+3',
#        '0', '-4', '-1'], dtype=object)

# %%
df["Like"]=df["Like"].replace({"-3":-3,"+2":2,"+1":1,"+4":4,"I love it!+5":5,"I hate it!-5":-5,"5":5,"-2":2,"+3":3,"0":0,"-4":4,"-1":1})

# %%
df["Like"].unique()
# Out:
# array([-3,  2,  1,  4,  5, -5,  3,  0], dtype=int64)

# %%
X=df.drop("VisitFrequency",axis=1)
y=df["VisitFrequency"]
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
pca = PCA(n_components=5)

# %%
data_pca=pca.fit_transform(X)

# %%
df_pca = pd.DataFrame(data_pca, columns=["pca-1", "pca-2","pca-3","pca-4","pca-5"])

# %%
df_pca
# Out:
#          pca-1     pca-2     pca-3     pca-4     pca-5
# 0     1.358169 -1.304607  0.427563 -0.503093 -1.743989
# 1    -0.660007  0.691872 -0.912815  0.035813 -0.363588
# 2     0.211065  0.671003  1.405153  3.218502 -0.242704
# 3    -0.399257 -0.924597 -1.048941  0.344022  0.205223
# 4     0.105312 -1.296112 -0.032814  0.553345  0.472734
# ...        ...       ...       ...       ...       ...
# 1448  4.107067  1.147370  0.644742 -0.218504  0.358429
# 1449 -1.626781  0.135114  0.860998 -1.345970  1.850166
# 1450 -0.771073  1.466705  0.481715 -0.575045 -1.623760
# 1451 -2.741975 -0.539388  2.038871 -0.181553  1.228953
# 1452  3.711167  1.706583  0.171408 -0.401442  0.811745
#
# [1453 rows x 5 columns]
